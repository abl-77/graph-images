# %%
from transformers import SegformerFeatureExtractor, SegformerForSemanticSegmentation
from PIL import Image
import torch

# Load pre-trained model
model = SegformerForSemanticSegmentation.from_pretrained("nvidia/segformer-b0-finetuned-ade-512-512")
feature_extractor = SegformerFeatureExtractor.from_pretrained("nvidia/segformer-b0-finetuned-ade-512-512")

image = Image.open("Real faces/1.R.B.F.png").convert("RGB")
inputs = feature_extractor(images=image, return_tensors="pt")
outputs = model(**inputs)
segmentation = torch.argmax(outputs.logits, dim=1)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 6
#       3 import torch
#       5 # Load pre-trained model
# ----> 6 model = SegformerForSemanticSegmentation.from_pretrained("nvidia/segformer-b0-finetuned-ade-512-512")
#       7 feature_extractor = SegformerFeatureExtractor.from_pretrained("nvidia/segformer-b0-finetuned-ade-512-512")
#       9 image = Image.open("Real faces/1.R.B.F.png").convert("RGB")
#
# File /opt/anaconda3/envs/csds446/lib/python3.9/site-packages/transformers/utils/import_utils.py:1840, in DummyObject.__getattribute__(cls, key)
#    1838 if key.startswith("_") and key != "_from_config":
#    1839     return super().__getattribute__(key)
# -> 1840 requires_backends(cls, cls._backends)
#
# File /opt/anaconda3/envs/csds446/lib/python3.9/site-packages/transformers/utils/import_utils.py:1828, in requires_backends(obj, backends)
#    1826 failed = [msg.format(name) for available, msg in checks if not available()]
#    1827 if failed:
# -> 1828     raise ImportError("".join(failed))
#
# ImportError:
# SegformerForSemanticSegmentation requires the PyTorch library but it was not found in your environment. Checkout the instructions on the
# installation page: https://pytorch.org/get-started/locally/ and follow the ones that match your environment.
# Please note that you may need to restart your runtime after installation.
